# %% [markdown]
# <a href="https://colab.research.google.com/github/DeisyData/BIT_IA_Bootcamp/blob/main/S13_C1_Hugging_Face_Transformes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Paso 1. Instalar trasnsformer e importar pipelines

# %%
# !pip install transformers
# !pip install timm

# %%
from transformers import pipeline

# %% [markdown]
# [Pipelines](https://huggingface.co/docs/transformers/main/en/main_classes/pipelines)

# %% [markdown]
# Probando ell ejemploo de Hugging

# %%
pipe = pipeline(model="FacebookAI/roberta-large-mnli")
# Out:
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Some weights of the model checkpoint at FacebookAI/roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# ...

# %%
pipe("This restaurant is awesome")
# Out:
# [{'label': 'NEUTRAL', 'score': 0.7313132882118225}]

# %% [markdown]
# Paso 2. Usar un modelo de clasificacion de imagenes

# %%
class_image = pipeline(task = "image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cpu

# %%
class_image("/content/pizza3.jpg")
# Out:
# [{'label': 'pizza, pizza pie', 'score': 0.9843366146087646},
#  {'label': 'French loaf', 'score': 0.00098368467297405},
#  {'label': 'frying pan, frypan, skillet', 'score': 0.0008834329782985151},
#  {'label': 'plate', 'score': 0.0008828055579215288},
#  {'label': 'restaurant, eating house, eating place, eatery',
#   'score': 0.0008017105283215642}]

# %%
class_image_2 = pipeline("image-classification", model="facebook/convnext-large-224")
# Out:
# config.json:   0%|          | 0.00/69.6k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/791M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/266 [00:00<?, ?B/s]
# Device set to use cpu

# %%
class_image_2("/content/pizza3.jpg")
# Out:
# [{'label': 'pizza, pizza pie', 'score': 0.9261889457702637},
#  {'label': 'French loaf', 'score': 0.0035457564517855644},
#  {'label': 'spatula', 'score': 0.0007880455232225358},
#  {'label': 'carbonara', 'score': 0.0006538630113936961},
#  {'label': 'potpie', 'score': 0.0005474179633893073}]

# %% [markdown]
# Paso 3. Usar un modelo de **Segmetación de Imagenes**

# %%
segmentation_1 = pipeline(task="image-segmentation")
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50-panoptic and revision d53b52a (https://huggingface.co/facebook/detr-resnet-50-panoptic).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/172M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/detr-resnet-50-panoptic were not used when initializing DetrForSegmentation: ['detr.model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# ...

# %%
segmentation_1("/content/Imagenoficina.jpg")
# Out:
# `label_ids_to_fuse` unset. No instance will be fused.
# [{'score': 0.998245,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.92824,
#   'label': 'cup',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.902603,
#   'label': 'chair',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.933143,
#   'label': 'car',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.995324,
#   'label': 'chair',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.977231,
#   'label': 'LABEL_189',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.996119,
#   'label': 'tv',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.999396,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': 0.999351,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
# ...

# %%
# !pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.4/899.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.6 MB/s eta 0:00:00
# ...

# %%
segmetation_2 = pipeline(model="openmmlab/upernet-convnext-small")
# Out:
# config.json:   0%|          | 0.00/8.76k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/328M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/372 [00:00<?, ?B/s]
# Device set to use cpu

# %%
segmetation_2("/content/Imagenoficina.jpg")
# Out:
# [{'score': None,
#   'label': 'wall',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'floor',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'windowpane',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'door',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'table',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'chair',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'painting',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'desk',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
#  {'score': None,
#   'label': 'box',
#   'mask': <PIL.Image.Image image mode=L size=612x408>},
# ...

# %%
from transformers import AutoImageProcessor, UperNetForSemanticSegmentation

processor = AutoImageProcessor.from_pretrained("openmmlab/upernet-convnext-small")
model = UperNetForSemanticSegmentation.from_pretrained("openmmlab/upernet-convnext-small")
